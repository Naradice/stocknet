# %%
class FXEnv:
    def __init__(self, isTraining = True, data = None, featureFirst=False, randomizeInitialState = True):
        if data == None:
            rates = rates = pd.read_csv('/mnt/landisk/data/fx/NextBoaderPossibility/fx_USDJPY_5_2020-08-03T23-05-00_to_2021-12-04T07-50-00.csv', header=0, index_col=0, parse_dates=True)
        else:
            rates = data
        self.rowdata = rates
        diff_array = rates.diff()
        self.data = pd.DataFrame(diff_array, columns=['time', 'open', 'high', 'low', 'close', 'tick_volume', 'spread', 'real_volume'])
        self.data = self.data.drop(columns=['time', 'real_volume'])
        self.data.tick_volume, _, _ = self.minmaxNormalization(rates.tick_volume)
        self.data.spread, self.minSp, self.maxSp = self.minmaxNormalization(rates.spread)
        df_budget = pd.Series([1 for i in range(0, len(self.data))])
        df_asb_diff = pd.Series([0 for i in range(0, len(self.data))])
        self.data = self.data[1:]
        self.rowdata = self.rowdata[1:]
        self.FF = featureFirst
        self.RIS = randomizeInitialState
        length = len(self.data)
        
        self.budget_org = 100000
        self.leverage = 25
        self.volume_point = 10000
        self.point = 0.001

        self.dataRange = datetime.timedelta(days=2)
        self.dims = 5
        INTERVAL_DAYS = 3
        MINUTES_SPAN = 5
        
        totalMinutes = INTERVAL_DAYS * 24 * 60
        self.span  = int(totalMinutes/MINUTES_SPAN)+1
        
        ##select random indices.
        self.indices = random.sample(range(self.span, length - self.span -1), k=length - self.span*2 -1)
        if isTraining:
            self.fromIndex = self.span
            self.toIndex = int(length*0.7)
        else:
            self.fromIndex = int(length*0.7)+1
            self.toIndex = length+1
            
        #For Reinforce lerning
        self.action_space = gym.spaces.Discrete(3+2)
        self.observation_space = gym.spaces.Box(
            low=-1,
            high=1,
            shape=(self.span,6)
        )
        self.reward_range = [-1, 1]
        self.VALID_REWARD = 0
        self.INVALID_REWARD = -.001
        self.reset()

    def __len__(self):
        return self.toIndex - self.fromIndex
    
    def reset(self):
        '''
        '''
        self.askPositions = []
        self.bidPositions = []
        self.budget = self.budget_org
        self.coin = 0
        if self.RIS:
            self.index = random.randint(self.fromIndex, self.toIndex)
        else:
            self.index = self.fromIndex
        self.stepCount = 0
        self.rewards = 0
        self.winCount = 0
        self.orderCount = 0
        self.pl = 0
        self.budget_history = [1 for i in range(0, self.span)]
        self.ask_diff_history = [0 for i in range(0, self.span)]
        self.bid_diff_history = [0 for i in range(0, self.span)]
        observations = self.__getitem__(self.index + self.stepCount)
        observations = numpy.hstack([observations, numpy.atleast_2d(self.budget_history).T])
        observations = numpy.hstack([observations, numpy.atleast_2d(self.ask_diff_history).T])
        observations = numpy.hstack([observations, numpy.atleast_2d(self.bid_diff_history).T])
        if self.FF:
            observations = observations.T
        return observations
    
    def getSymbolInfo(self, symbol='USDJPY'):
        if symbol == 'USDJPY':
             return {
                 "point": 0.001,
                 "min":0.1,
                 "rate":100000
             }
    
    def GET_CURRENT_ASK(self):
        if self.index + self.stepCount < len(self.rowdata):
            value = self.rowdata.close.iloc[self.index + self.stepCount -1]  + self.rowdata["spread"].iloc[self.index + self.stepCount -1]*self.point
            #value = random.uniform(next_data["Open"].iloc[0], next_data["High"].iloc[0])
            #value = next_data["Open"].iloc[0] + next_data["spread"].iloc[0]*self.point
            return value
        
    def GET_CURRENT_BID(self):
        if self.index + self.stepCount < len(self.rowdata):
            value = self.rowdata.close.iloc[self.index + self.stepCount -1]  - self.rowdata["spread"].iloc[self.index + self.stepCount -1]*self.point
            #value = random.uniform(next_data["Low"].iloc[0], next_data["Open"].iloc[0])
            #value = next_data["Open"].iloc[0] - next_data["spread"].iloc[0]*self.point
            return value
    
    def __getRowData__(self, ndx):
        inputs = []
        if type(ndx) == slice:
            for index in self.indices[ndx]:
                inputs.append(self.rowdata[index+1-self.span:index+1].values.tolist())
        else:
            index = ndx
            inputs = self.rowdata[index+1-self.span:index+1].values.tolist()

        return inputs
    
    def __getInputs__(self, ndx):
        inputs = []
        if type(ndx) == int:
            indicies = slice(ndx, ndx+1)
            for index in self.indices[indicies]:
                inputs.append(self.data[index+1-self.span:index+1].values.tolist())
            return inputs[0]
        elif type(ndx) == slice:
            indicies = ndx
            for index in self.indices[indicies]:
                inputs.append(self.data[index+1-self.span:index+1].values.tolist())
            return inputs
    
    def __getActialIndex__(self,ndx):
        inputs = []
        if type(ndx) == slice:
            for index in self.indices[ndx]:
                inputs.append(index)
        else:
            inputs = self.indices[ndx]

        return inputs
    
    def __getitem__(self, ndx):
        ins = numpy.array(self.__getInputs__(ndx), dtype=numpy.dtype('float32'))
        return ins
        #return ins, outputs
    
    def minmaxNormalization(self, data):
        if type(data) == numpy.ndarray:
            temp_data = data[~numpy.isnan(data)]
        elif type(data) == pd.core.series.Series:
            temp_data = data.dropna()
        else:
            print(f"unkown type: {type(data)}")
            temp_data = data
        X_max, X_min = max(temp_data), min(temp_data)
        data_norm = (data - X_min) / (X_max - X_min)
        return data_norm, X_min, X_max

    def denormalization(self, value, X_min, X_max):
        return value * (X_max - X_min) + X_min
    
    def badget_in_use_and_diff(self):
        budget_in_use = 0
        ask_diff = 0
        bid_diff = 0
        sell_price = self.GET_CURRENT_BID()
        ask_price = self.GET_CURRENT_ASK()
        for position in self.askPositions:
            ask_diff += (sell_price - position['price'])/position['price']
            budget_in_use += position['volume']*sell_price*self.volume_point/self.leverage
        for position in self.bidPositions:
            bid_diff += (position['price'] - ask_price)/ask_price
            budget_in_use += position['volume']*ask_price*self.volume_point/self.leverage
        return budget_in_use, ask_diff, bid_diff

    def evaluate(self, action):
        reward = 0
        if action == 1:
            '''
            buy coin with 10 point if possible.
            if you don't have much budget, return negative reward 
            '''
            reward = self.__buy__()

        elif action == 2:
            '''
            sell coin with 10 point if possible.
            if you don't have much budget, return negative reward
            '''
            reward = self.__sell__()

        elif action == 0:
            '''
            hold. reward is 0
            '''
            reward = self.__stay__()
        elif action == 3:
            '''
            buy settlement of bid position.
            if there are no position, return negative reward
            '''
            reward = self.__settlement__("buy")
        elif action == 4:
            '''
            sell settlement of ask position.
            if there are no position, return negative reward
            '''
            reward = self.__settlement__("sell")
        else:
            raise Exception(f"The action number {action} exeeds the lengths in evaluate function.")
        return reward
    
    def step(self, action): # actionを実行し、結果を返す
        self.stepCount += 1
        if self.index + self.stepCount <= self.toIndex:
            done = False
            reward = 0.0
            option = None
            reward = self.evaluate(action)
            self.rewards = self.rewards + reward

            budget_in_use, ask_diff, bid_diff = self.badget_in_use_and_diff()
            option = [self.budget/self.budget_org, ask_diff, bid_diff]
            #budget
            observations = self.__getitem__(self.index + self.stepCount)
            self.budget_history[:-1] = self.budget_history[1:]
            self.budget_history[-1] = self.budget/self.budget_org
            self.ask_diff_history[:-1] = self.ask_diff_history[1:]
            self.ask_diff_history[-1] = ask_diff
            self.bid_diff_history[:-1] = self.ask_diff_history[1:]
            self.bid_diff_history[-1] = bid_diff
            observations = numpy.hstack([observations, numpy.atleast_2d(self.budget_history).T])
            observations = numpy.hstack([observations, numpy.atleast_2d(self.ask_diff_history).T])
            observations = numpy.hstack([observations, numpy.atleast_2d(self.bid_diff_history).T])
            if self.FF:
                observations = observations.T

            
            if self.orderCount > 0:
                winRate = self.winCount/self.orderCount
            else:
                winRate = -1
            
            #if (self.budget + budget_in_use) - self.budget_org < - self.budget_org * 0.2:
            if self.pl < -10:
                done = True
            else:
                done = False
            #if self.orderCount < 12*24*30 or self.pl > 0:
                #done = False
            return observations, reward, done, option
        else:
            observations = self.__getitem__(self.index + self.stepCount-1)
            ask_diff = 0
            sell_price = self.GET_CURRENT_BID()
            budget_in_use, ask_diff, bid_diff = self.badget_in_use_and_diff()
            self.budget_history[:-1] = self.budget_history[1:]
            self.budget_history[-1] = self.budget/self.budget_org
            self.ask_diff_history[:-1] = self.ask_diff_history[1:]
            self.ask_diff_history[-1] = ask_diff
            self.bid_diff_history[:-1] = self.ask_diff_history[1:]
            self.bid_diff_history[-1] = bid_diff
            observations = numpy.hstack([observations, numpy.atleast_2d(self.budget_history).T])
            observations = numpy.hstack([observations, numpy.atleast_2d(self.ask_diff_history).T])
            observations = numpy.hstack([observations, numpy.atleast_2d(self.bid_diff_history).T])
            print("index end")
            if self.FF:
                observations = observations.T
            return observations, 0, True, {}
        
    def render(self, mode='human', close=False):
        '''
        '''
        ask_diff = 0
        sell_price = self.GET_CURRENT_BID()
        budget_in_use, _, _ = self.badget_in_use_and_diff()
        if self.orderCount > 0:
            winRate = self.winCount/self.orderCount
        else:
            winRate = -1
        print (f"budget:{self.budget} + {budget_in_use}, pl:{self.pl}, winRate:{winRate}")

    def __stay__(self, S=5, T=1/2):
        reward = 0.0
        sell_price = self.GET_CURRENT_BID()
        for position in self.askPositions:
            ask_diff = (sell_price - position['price'])/position['price']
            if position['step'] < S:
                alpha = (position['step'] - self.stepCount)/S * T
            else:
                alpha = T
            reward += alpha * ask_diff
        ask_price = self.GET_CURRENT_ASK()
        for position in self.bidPositions:
            bid_diff = (position['price'] - ask_price)/ask_price
            if position['step'] < S:
                alpha = (position['step'] - self.stepCount)/S * T
            else:
                alpha = T
            reward += alpha * bid_diff
        #raise Exception(f"Unexpected action value in __stay__ function: {action}")

        return reward
    
    def close(self):
        '''
        '''
        pass
    
    def seed(self, seed=None):
        '''
        '''
        if seed == None:
            random.seed(1017)
        else:
            random.seed(seed)

    def __settlement__(self, type, price=None):
        reward = 0
        # settlement bid position
        if type == "buy":
            if len(self.bidPositions) > 0 and len(self.askPositions) > 0: #全額売買のみ　かつ　両建て無し
                #print("buy settlement")
                reward = self.VALID_REWARD
                current_buy_rate = self.GET_CURRENT_ASK()
                for position in self.bidPositions:
                    reward += (position['price'] - current_buy_rate)/current_buy_rate
                    self.budget += (position['volume'] * self.volume_point * current_buy_rate)/self.leverage
                    #print(f"actual reward: {((position['price'] - current_buy_rate))}")
                    #print(f"BID SETTLEMENT: {position['price']} - {current_buy_rate} = {position['price'] - current_buy_rate}")
                    pl = position['price'] - current_buy_rate
                    #print(pl)
                    self.pl += pl
                    if pl > 0:
                        self.winCount += 1
                    else:
                        # twice
                        reward += (position['price'] - current_buy_rate)/current_buy_rate
                self.bidPositions = [] 
            else:
                reward = self.INVALID_REWARD
        elif type == "sell":# settlement ask position
            reward = self.VALID_REWARD
            if len(self.askPositions) > 0 and len(self.bidPositions) > 0:
                #print("sell settlement")
                current_sell_rate = self.GET_CURRENT_BID()
                for position in self.askPositions:
                    reward += (current_sell_rate - position['price'])/position['price']
                    self.budget += (position['volume'] * self.volume_point * current_sell_rate)/self.leverage
                    #print(f"actual reward: {((current_sell_rate - position['price']))}")
                    #print(f"ASK SETTLEMENT: {current_sell_rate} - {position['price']} = {current_sell_rate - position['price']}")
                    pl = current_sell_rate - position['price']
                    self.pl += pl
                    #print(pl)
                    if pl >0:
                        self.winCount += 1
                    else:
                        # twice
                        reward += (current_sell_rate - position['price'])/position['price']
                self.askPositions = []
            else:
                reward = self.INVALID_REWARD
        #print(f"{self.budget}, {reward}")
        return reward
    
    def __buy__(self, volume=0.1):
        current_buy_rate = self.GET_CURRENT_ASK()
        reward = 0
        required_budget = (volume * self.volume_point * current_buy_rate)/self.leverage
        #if self.budget > required_budget:
        if len(self.askPositions) == 0:
            reward = self.VALID_REWARD
            means = self.rowdata.close.rolling(12).mean()
            mean = means.iloc[-1]
            #reward = (mean - current_buy_rate)/mean
            position = {'volume': volume, 'price': current_buy_rate, 'step':self.stepCount}
            self.askPositions.append(position)
            self.budget = self.budget -  required_budget
            self.orderCount +=1
        else:
            reward = self.INVALID_REWARD
            #reward = 0
        return reward
        
    def __sell__(self, volume=0.1):
        current_sell_rate = self.GET_CURRENT_BID()
        reward = 0
        required_budget = (volume * self.volume_point * current_sell_rate)/self.leverage
        #if self.budget > required_budget:
        if len(self.bidPositions) == 0:
            reward = self.VALID_REWARD
            means = self.rowdata.close.rolling(12).mean()
            mean = means.iloc[-1]
            #eward = (current_sell_rate - mean)/mean
            position = {'volume': volume, 'price': current_sell_rate, 'step':self.stepCount}
            #if self.budget * self.leverage >= volume*self.volume_point * current_sell_rate:
            self.bidPositions.append(position)
            self.budget = self.budget -  required_budget
            self.orderCount +=1
        else:
            reward = self.INVALID_REWARD
            #reward = 0
        return reward

# %%
env = FXEnv(featureFirst=True)

# %%
import pfrl
import torch.nn.functional as F
import torch.nn as nn
import torch
import random
import numpy
import datetime

# %%
import torch
import torch.nn as nn
from torch.optim import SGD
import math
import numpy as np

class PredictorSimple(nn.Module):
    def __init__(self, size, inputDim, n_actions, removeHistoryData = True):
        super().__init__()
        self.size = size
        self.rhd = removeHistoryData
        self.inDim = inputDim
        self.ActionHistoryDim = 3
        self.conv1 = nn.Conv1d(inputDim, inputDim*3, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(inputDim*3, inputDim*2, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(inputDim*2*size, inputDim*size)
        self.fc2 = nn.Linear(inputDim*size, size)
        self.output_layer = nn.Linear(size, n_actions)
        self.softmax = nn.Softmax(1)

    def forward(self, inputs):
        batch_size, feature_len, seq_len  = inputs.shape[0], inputs.shape[1],inputs.shape[2]
        if self.rhd:
            out = inputs[:,0: feature_len - self.ActionHistoryDim, :]
        else:
            out = inputs
        out = F.relu(self.conv1(out))
        out = F.relu(self.conv2(out))
        out = out.view(-1, self.inDim*2*self.size)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.output_layer(out)
        return pfrl.action_value.DiscreteActionValue(out)

# %%
import torch
import torch.nn as nn
from torch.optim import SGD
import math
import numpy as np

class Predictor(nn.Module):
    def __init__(self, inputDim, hiddenDim,  n_actions):
        super(Predictor, self).__init__()
        self.ActionHistoryDim = 3
        self.rnn = nn.LSTM(input_size = inputDim,
                            hidden_size = hiddenDim,
                            batch_first=True)
        self.rnn.to(device)
        self.output_layer = nn.Linear(hiddenDim, n_actions)#+self.ActionHistoryDim, n_actions)
        self.output_layer.to(device)
    
    def forward(self, inputs, hidden0=None):
        batch_size, seq_len, feature_len = inputs.shape[0], inputs.shape[1],inputs.shape[2]
        ohlc_inputs = inputs[:,:, 0: feature_len - self.ActionHistoryDim]
        last_actions = inputs[:, -1, -self.ActionHistoryDim:] # [1, ActionHistoryDim] (ex.torch.Size([1, 3]))
        output, (hidden, cell) = self.rnn(ohlc_inputs, hidden0) #LSTM層
        output = output[:, -1, :] # [1, hiddenDim] (ex. torch.Size([1, 50]))
        #output = torch.cat((output, last_actions), dim=1) #[1, hiddenDim+ActionHistoryDim] (ex.torch.Size([1, 53]))
        output = self.output_layer(output) #全結合層
        return pfrl.action_value.DiscreteActionValue(output)

# %%
training_size = 1000 #traning dataのデータ数
epochs_num = 10000 #traningのepoch回数
hidden_size = 500 #LSTMの隠れ層の次元数
batch_size = 32

# %%
obs = env.reset()
size = obs.shape[1]

# %%
obs.shape
# Out:
# (9, 865)

# %%
model = PredictorSimple(size, 9, 5, False) #modelの宣言

#model = Predictor(6, hidden_size, 5) #modelの宣言
criterion = nn.MSELoss() #評価関数の宣言

# %%
#optimizer = SGD(model.parameters(), lr=0.0001) #最適化関数の宣言
optimizer = torch.optim.Adam(model.parameters(), eps=1e-9)
# Set the discount factor that discounts future rewards.
gamma = 0.9

# Use epsilon-greedy for exploration
explorer = pfrl.explorers.ConstantEpsilonGreedy(
    epsilon=0.3, random_action_func=env.action_space.sample)

# DQN uses Experience Replay.}
# Specify a replay buffer and its capacity.
replay_buffer = pfrl.replay_buffers.ReplayBuffer(capacity=10**2)

# Since observations from CartPole-v0 is numpy.float64 while
# As PyTorch only accepts numpy.float32 by default, specify
# a converter as a feature extractor function phi.
phi = lambda x: x.astype(numpy.float32, copy=False)

# Set the device id to use GPU. To use CPU only, set it to -1.
gpu = 0

# Now create an agent that will interact with the environment.
agent = pfrl.agents.DoubleDQN(
    model,
    optimizer,
    replay_buffer,
    gamma,
    explorer,
    replay_start_size=40,
    update_interval=5,
    target_update_interval=20,
    phi=phi,
    gpu=gpu,
)

# %%
n_episodes = 1000
max_step_len = 10000
print(datetime.datetime.now(),'start episodes')
for i in range(1, n_episodes + 1):
    obs = env.reset()
    #obs = obs.to('cpu').detach().numpy().copy()
    R = 0  # return (sum of rewards)
    t = 0  # time step
    while True:
        # Uncomment to watch the behavior in a GUI window
        #env.render()
        action = agent.act(obs)
        obs, reward, done, ops = env.step(action)
        #obs = obs.to('cpu').detach().numpy().copy()
        R += reward
        t += 1
        reset = t == max_step_len
        agent.observe(obs, reward, done, reset)
        if reset:
            print("max steps")
            break
        elif done:
            break
    env.render()
    #print(datetime.datetime.now(),'episode:', i, 'R:', R)
    print('statistics:', agent.get_statistics())
    #if i % 50 == 0:
print('Finished.')
# Out:
# 2022-02-20 18:55:32.947121 start episodes
# max steps
# budget:95797.4 + 4362.56, pl:-0.4600000000002069, winRate:0.4152542372881356
# statistics: [('average_q', 0.0035779413), ('average_loss', 1.7016625214694159e-07), ('cumulative_steps', 53583), ('n_updates', 10709), ('rlen', 100)]
# max steps
# budget:91417.28000000001 + 8777.92, pl:-4.353999999999658, winRate:0.39300411522633744
# statistics: [('average_q', -0.0044779414), ('average_loss', 1.6221727225484983e-07), ('cumulative_steps', 63583), ('n_updates', 12709), ('rlen', 100)]
# budget:95700.35999999999 + 4220.76, pl:-10.078999999999851, winRate:0.38596491228070173
# statistics: [('average_q', -0.00041051424), ('average_loss', 1.913931938446467e-07), ('cumulative_steps', 71057), ('n_updates', 14204), ('rlen', 100)]
# max steps
# budget:95656.80000000002 + 4369.639999999999, pl:-3.8310000000003157, winRate:0.35730337078651686
# statistics: [('average_q', 0.0006851731), ('average_loss', 2.9632868553619573e-07), ('cumulative_steps', 81057), ('n_updates', 16204), ('rlen', 100)]
# max steps
# budget:95764.48000000021 + 4375.52, pl:-3.9270000000000067, winRate:0.4233128834355828
# statistics: [('average_q', -0.0043769325), ('average_loss', 3.526499096651037e-07), ('cumulative_steps', 91057), ('n_updates', 18204), ('rlen', 100)]
# max steps
# budget:95749.40000000011 + 4132.24, pl:-7.55000000000021, winRate:0.4323770491803279
# statistics: [('average_q', 0.00040365665), ('average_loss', 1.992200578015968e-07), ('cumulative_steps', 101057), ('n_updates', 20204), ('rlen', 100)]
# index end
# budget:95634.91999999993 + 4411.88, pl:-7.456000000000003, winRate:0.3919491525423729
# statistics: [('average_q', -0.0014237639), ('average_loss', 1.925775403854857e-07), ('cumulative_steps', 110820), ('n_updates', 22157), ('rlen', 100)]
# index end
# budget:91230.91999999987 + 8824.0, pl:-6.837999999999809, winRate:0.39227642276422764
# statistics: [('average_q', 0.0016953752), ('average_loss', 1.460586385348961e-07), ('cumulative_steps', 120713), ('n_updates', 24135), ('rlen', 100)]
# max steps
# budget:95632.95999999993 + 4384.44, pl:-4.751000000000218, winRate:0.4129979035639413
# statistics: [('average_q', 0.002033639), ('average_loss', 1.1583470914899862e-07), ('cumulative_steps', 130713), ('n_updates', 26135), ('rlen', 100)]
# max steps
# budget:91561.12000000023 + 8378.64, pl:-2.82800000000006, winRate:0.3816326530612245
# statistics: [('average_q', -0.003567838), ('average_loss', 4.238741544781988e-07), ('cumulative_steps', 140713), ('n_updates', 28135), ('rlen', 100)]
# max steps
# budget:95637.68000000005 + 4216.72, pl:-3.2610000000005215, winRate:0.41541755888650966
# statistics: [('average_q', 0.00033985407), ('average_loss', 9.81662004306827e-08), ('cumulative_steps', 150713), ('n_updates', 30135), ('rlen', 100)]
# max steps
# budget:95670.15999999997 + 4220.32, pl:-6.411000000000072, winRate:0.44031311154598823
# statistics: [('average_q', 0.0017724367), ('average_loss', 8.296702298959957e-08), ('cumulative_steps', 160713), ('n_updates', 32135), ('rlen', 100)]
# index end
# budget:91160.51999999997 + 8824.0, pl:-1.4350000000000165, winRate:0.4748201438848921
# statistics: [('average_q', -0.0012858367), ('average_loss', 1.7710212594224117e-07), ('cumulative_steps', 163379), ('n_updates', 32668), ('rlen', 100)]
# max steps
# budget:95675.40000000002 + 4376.12, pl:-2.6399999999999295, winRate:0.44130434782608696
# statistics: [('average_q', 0.0008025365), ('average_loss', 1.3315315118944683e-07), ('cumulative_steps', 173379), ('n_updates', 34668), ('rlen', 100)]
# max steps
# budget:91540.64000000013 + 8708.880000000001, pl:-6.133000000000081, winRate:0.4264705882352941
# statistics: [('average_q', 0.0044475915), ('average_loss', 1.6589424403079534e-07), ('cumulative_steps', 183379), ('n_updates', 36668), ('rlen', 100)]
# max steps
# budget:95618.44000000005 + 4434.52, pl:-1.052000000000234, winRate:0.430327868852459
# statistics: [('average_q', 0.0025986135), ('average_loss', 1.5402434490496831e-07), ('cumulative_steps', 193379), ('n_updates', 38668), ('rlen', 100)]
# max steps
# budget:95816.27999999988 + 4225.56, pl:-4.349000000000203, winRate:0.39019189765458423
# statistics: [('average_q', -0.00020757806), ('average_loss', 1.2180540553075049e-07), ('cumulative_steps', 203379), ('n_updates', 40668), ('rlen', 100)]
# max steps
# budget:95735.1200000001 + 4180.8, pl:-2.7659999999997495, winRate:0.38729508196721313
# statistics: [('average_q', -0.0036539638), ('average_loss', 3.709724273903703e-07), ('cumulative_steps', 213379), ('n_updates', 42668), ('rlen', 100)]
# max steps
# budget:95815.9199999999 + 4162.000000000001, pl:-6.989000000000189, winRate:0.3907815631262525
# statistics: [('average_q', 0.0023474752), ('average_loss', 2.254605205820326e-07), ('cumulative_steps', 223379), ('n_updates', 44668), ('rlen', 100)]
# max steps
# budget:95867.9200000001 + 4188.64, pl:-6.968000000000359, winRate:0.3870967741935484
# statistics: [('average_q', -0.0004994616), ('average_loss', 2.326783140027544e-07), ('cumulative_steps', 233379), ('n_updates', 46668), ('rlen', 100)]
# index end
# budget:95582.51999999993 + 4412.12, pl:-5.396999999999849, winRate:0.39429928741092635
# statistics: [('average_q', -0.001960644), ('average_loss', 1.2930684057721463e-07), ('cumulative_steps', 242131), ('n_updates', 48419), ('rlen', 100)]
# max steps
# budget:91711.16000000013 + 8290.800000000001, pl:-0.8550000000002598, winRate:0.4217391304347826
# statistics: [('average_q', 0.0011336983), ('average_loss', 1.566273495612336e-07), ('cumulative_steps', 252131), ('n_updates', 50419), ('rlen', 100)]
# max steps
# budget:95884.79999999997 + 4366.56, pl:-4.622999999999678, winRate:0.3983402489626556
# statistics: [('average_q', -0.0010668952), ('average_loss', 2.525596237035188e-07), ('cumulative_steps', 262131), ('n_updates', 52419), ('rlen', 100)]
# max steps
# budget:91639.23999999998 + 8296.48, pl:-5.023999999999802, winRate:0.4308617234468938
# statistics: [('average_q', -0.002407778), ('average_loss', 9.605418540559186e-08), ('cumulative_steps', 272131), ('n_updates', 54419), ('rlen', 100)]
# max steps
# budget:91590.87999999999 + 8437.68, pl:-7.391000000000233, winRate:0.3747276688453159
# statistics: [('average_q', -0.0018518952), ('average_loss', 2.0971479589348973e-07), ('cumulative_steps', 282131), ('n_updates', 56419), ('rlen', 100)]
# max steps
# budget:91612.99999999999 + 8403.600000000002, pl:-4.6400000000003985, winRate:0.39748953974895396
# statistics: [('average_q', -0.0006427253), ('average_loss', 8.125626179911194e-08), ('cumulative_steps', 292131), ('n_updates', 58419), ('rlen', 100)]
# max steps
# budget:95849.3200000001 + 4355.280000000001, pl:-7.8539999999998145, winRate:0.43004115226337447
# statistics: [('average_q', -0.002894241), ('average_loss', 1.3246152752444118e-07), ('cumulative_steps', 302131), ('n_updates', 60419), ('rlen', 100)]
# max steps
# budget:95817.71999999997 + 4129.72, pl:-3.0270000000002284, winRate:0.4053497942386831
# statistics: [('average_q', -0.00027280118), ('average_loss', 5.993089555289544e-07), ('cumulative_steps', 312131), ('n_updates', 62419), ('rlen', 100)]
# max steps
# budget:91482.11999999997 + 8699.44, pl:-5.872999999999948, winRate:0.4173076923076923
# statistics: [('average_q', -0.0020962153), ('average_loss', 1.9373787214505e-07), ('cumulative_steps', 322131), ('n_updates', 64419), ('rlen', 100)]
# max steps
# budget:95815.75999999983 + 4202.160000000001, pl:-5.214999999999819, winRate:0.3969957081545064
# statistics: [('average_q', -0.0034081284), ('average_loss', 1.0153201957407986e-07), ('cumulative_steps', 332131), ('n_updates', 66419), ('rlen', 100)]
# max steps
# budget:95811.0 + 4225.000000000001, pl:-5.582999999999842, winRate:0.37995824634655534
# statistics: [('average_q', -0.0014456417), ('average_loss', 7.523604978132425e-08), ('cumulative_steps', 342131), ('n_updates', 68419), ('rlen', 100)]
# max steps
# budget:91541.32000000015 + 8720.560000000001, pl:-3.333999999999847, winRate:0.4383838383838384
# statistics: [('average_q', -0.0021463402), ('average_loss', 5.5126495261959e-07), ('cumulative_steps', 352131), ('n_updates', 70419), ('rlen', 100)]
# max steps
# budget:95702.44000000008 + 4191.76, pl:-6.06600000000013, winRate:0.3966597077244259
# statistics: [('average_q', 0.0030996366), ('average_loss', 1.2640749673664687e-07), ('cumulative_steps', 362131), ('n_updates', 72419), ('rlen', 100)]
# max steps
# budget:95850.75999999988 + 4376.28, pl:-5.363999999999933, winRate:0.402
# statistics: [('average_q', -0.0033291234), ('average_loss', 2.4917634313226243e-07), ('cumulative_steps', 372131), ('n_updates', 74419), ('rlen', 100)]
# index end
# budget:95618.19999999985 + 4411.88, pl:-2.376999999999782, winRate:0.3953488372093023
# statistics: [('average_q', -0.0016946463), ('average_loss', 2.8808021866666424e-07), ('cumulative_steps', 376853), ('n_updates', 75363), ('rlen', 100)]
# max steps
# budget:95900.96000000024 + 4426.2, pl:-5.203000000000031, winRate:0.39068825910931176
# statistics: [('average_q', 0.00061754824), ('average_loss', 5.201560186662846e-07), ('cumulative_steps', 386853), ('n_updates', 77363), ('rlen', 100)]
# index end
# budget:95548.92000000011 + 4411.88, pl:-0.3389999999998565, winRate:0.422680412371134
# statistics: [('average_q', -0.0033119754), ('average_loss', 1.4417408848999004e-07), ('cumulative_steps', 388602), ('n_updates', 77713), ('rlen', 100)]
# max steps
# budget:91659.19999999997 + 8327.52, pl:-4.760000000000332, winRate:0.4460285132382892
# statistics: [('average_q', -0.0012134078), ('average_loss', 1.0815208513648144e-07), ('cumulative_steps', 398602), ('n_updates', 79713), ('rlen', 100)]
# max steps
# budget:95635.47999999994 + 4403.4800000000005, pl:-1.7949999999997885, winRate:0.4177215189873418
# statistics: [('average_q', -7.13025e-06), ('average_loss', 1.630207833436259e-07), ('cumulative_steps', 408602), ('n_updates', 81713), ('rlen', 100)]
# max steps
# budget:95889.31999999993 + 4151.960000000001, pl:-2.7730000000002235, winRate:0.41386554621848737
# statistics: [('average_q', -0.0017386411), ('average_loss', 1.1002463875087187e-07), ('cumulative_steps', 418602), ('n_updates', 83713), ('rlen', 100)]
# max steps
# budget:91624.76000000002 + 8305.52, pl:-3.901000000000039, winRate:0.41113490364025695
# statistics: [('average_q', -0.001914732), ('average_loss', 1.55763265237141e-07), ('cumulative_steps', 428602), ('n_updates', 85713), ('rlen', 100)]
# max steps
# budget:95817.44000000024 + 4413.04, pl:-1.3689999999999714, winRate:0.41163793103448276
# statistics: [('average_q', -0.0022769107), ('average_loss', 1.8967557878113438e-07), ('cumulative_steps', 438602), ('n_updates', 87713), ('rlen', 100)]
# max steps
# budget:95841.59999999969 + 4208.64, pl:-4.363000000000312, winRate:0.4282744282744283
# statistics: [('average_q', -0.0016729082), ('average_loss', 1.6148134786675429e-07), ('cumulative_steps', 448602), ('n_updates', 89713), ('rlen', 100)]
# max steps
# budget:95760.56 + 4179.24, pl:-3.9709999999999184, winRate:0.4244306418219462
# statistics: [('average_q', 0.012579968), ('average_loss', 1.6056507067574444e-06), ('cumulative_steps', 458602), ('n_updates', 91713), ('rlen', 100)]
# max steps
# budget:95681.23999999999 + 4437.280000000001, pl:-7.32500000000006, winRate:0.38028169014084506
# statistics: [('average_q', -0.0021658519), ('average_loss', 2.0425336686002993e-07), ('cumulative_steps', 468602), ('n_updates', 93713), ('rlen', 100)]
# max steps
# budget:95614.11999999994 + 4429.8, pl:-6.739000000000061, winRate:0.3996101364522417
# statistics: [('average_q', 0.00035877444), ('average_loss', 1.824429541130712e-07), ('cumulative_steps', 478602), ('n_updates', 95713), ('rlen', 100)]
# max steps
# budget:91669.24000000008 + 8445.760000000002, pl:-4.892999999999944, winRate:0.40350877192982454
# statistics: [('average_q', -0.0014462515), ('average_loss', 1.5530759404747129e-07), ('cumulative_steps', 488602), ('n_updates', 97713), ('rlen', 100)]
# max steps
# budget:95686.27999999993 + 4427.48, pl:-5.190000000000325, winRate:0.40210526315789474
# statistics: [('average_q', -0.0009821845), ('average_loss', 1.1962981854907184e-07), ('cumulative_steps', 498602), ('n_updates', 99713), ('rlen', 100)]
# index end
# budget:95564.72 + 4412.12, pl:-3.0539999999999594, winRate:0.41450777202072536
# statistics: [('average_q', 0.001923796), ('average_loss', 2.1221582457542354e-07), ('cumulative_steps', 502110), ('n_updates', 100415), ('rlen', 100)]
# index end
# budget:95616.24000000002 + 4411.88, pl:-0.8940000000002897, winRate:0.44680851063829785
# statistics: [('average_q', -0.0028465767), ('average_loss', 2.1271119969412665e-07), ('cumulative_steps', 509607), ('n_updates', 101914), ('rlen', 100)]
# index end
# budget:95538.55999999984 + 4412.12, pl:-2.370000000000047, winRate:0.40148698884758366
# statistics: [('average_q', -0.002613959), ('average_loss', 2.299877117906135e-07), ('cumulative_steps', 514829), ('n_updates', 102958), ('rlen', 100)]
# max steps
# budget:91678.87999999983 + 8441.920000000002, pl:-3.4300000000000495, winRate:0.4157782515991471
# statistics: [('average_q', -0.0028913512), ('average_loss', 1.1262858178540113e-07), ('cumulative_steps', 524829), ('n_updates', 104958), ('rlen', 100)]
# index end
# budget:95582.64 + 4412.12, pl:-3.6160000000000565, winRate:0.3935018050541516
# statistics: [('average_q', -0.0023844643), ('average_loss', 2.4232089522513435e-07), ('cumulative_steps', 530000), ('n_updates', 105993), ('rlen', 100)]
# index end
# budget:95595.44 + 4411.88, pl:-0.0940000000000083, winRate:0.2857142857142857
# statistics: [('average_q', -0.0011650176), ('average_loss', 1.1899203062881725e-07), ('cumulative_steps', 530226), ('n_updates', 106038), ('rlen', 100)]
# max steps
# budget:91660.44000000005 + 8298.32, pl:-3.742000000000303, winRate:0.4048140043763676
# statistics: [('average_q', 0.00057422894), ('average_loss', 1.3533765963913424e-07), ('cumulative_steps', 540226), ('n_updates', 108038), ('rlen', 100)]
# max steps
# budget:95749.83999999998 + 4148.88, pl:-2.5310000000003043, winRate:0.41735537190082644
# statistics: [('average_q', -0.0015455744), ('average_loss', 1.3635682468482458e-07), ('cumulative_steps', 550226), ('n_updates', 110038), ('rlen', 100)]
# max steps
# budget:95855.51999999984 + 4427.8, pl:-4.52300000000038, winRate:0.4701195219123506
# statistics: [('average_q', 0.00021786538), ('average_loss', 1.182123169485294e-07), ('cumulative_steps', 560226), ('n_updates', 112038), ('rlen', 100)]
# max steps
# budget:95843.43999999986 + 4248.36, pl:-5.442000000000007, winRate:0.4092741935483871
# statistics: [('average_q', -0.000900461), ('average_loss', 2.330905368452818e-07), ('cumulative_steps', 570226), ('n_updates', 114038), ('rlen', 100)]
# max steps
# budget:91243.16000000005 + 8865.52, pl:-4.3629999999999, winRate:0.4074074074074074
# statistics: [('average_q', -0.00029295342), ('average_loss', 2.1043971432987973e-07), ('cumulative_steps', 580226), ('n_updates', 116038), ('rlen', 100)]
# max steps
# budget:95766.8800000002 + 4165.72, pl:-4.624000000000379, winRate:0.4078674948240166
# statistics: [('average_q', -0.0017684853), ('average_loss', 1.1975783012374564e-07), ('cumulative_steps', 590226), ('n_updates', 118038), ('rlen', 100)]
# max steps
# budget:95835.56000000004 + 4423.960000000001, pl:-6.810000000000258, winRate:0.43052837573385516
# statistics: [('average_q', -0.0012322562), ('average_loss', 2.1360671823345e-07), ('cumulative_steps', 600226), ('n_updates', 120038), ('rlen', 100)]
# max steps
# budget:95828.07999999996 + 4158.04, pl:0.10599999999986665, winRate:0.4101010101010101
# statistics: [('average_q', -0.0026587679), ('average_loss', 1.844432807374119e-07), ('cumulative_steps', 610226), ('n_updates', 122038), ('rlen', 100)]
# max steps
# budget:91633.20000000019 + 8699.68, pl:-7.747000000000142, winRate:0.40471512770137524
# statistics: [('average_q', -0.00078040594), ('average_loss', 3.8048564938719663e-07), ('cumulative_steps', 620226), ('n_updates', 124038), ('rlen', 100)]
# max steps
# budget:95673.16000000005 + 4349.960000000001, pl:-3.2599999999997777, winRate:0.4419047619047619
# statistics: [('average_q', 0.003498071), ('average_loss', 1.7479107210505164e-07), ('cumulative_steps', 630226), ('n_updates', 126038), ('rlen', 100)]
# index end
# budget:95600.71999999997 + 4411.88, pl:-3.783000000000172, winRate:0.40189873417721517
# statistics: [('average_q', 0.0010473084), ('average_loss', 2.618267327925139e-07), ('cumulative_steps', 636526), ('n_updates', 127298), ('rlen', 100)]
# budget:95823.56000000014 + 4342.12, pl:-10.179000000000258, winRate:0.4069529652351738
# statistics: [('average_q', -0.0012652269), ('average_loss', 2.120227631685623e-07), ('cumulative_steps', 646042), ('n_updates', 129201), ('rlen', 100)]
# max steps
# budget:95638.99999999999 + 4369.64, pl:-5.615000000000123, winRate:0.3967611336032389
# statistics: [('average_q', -0.0012249196), ('average_loss', 4.1413808794743544e-07), ('cumulative_steps', 656042), ('n_updates', 131201), ('rlen', 100)]
# max steps
# budget:95735.71999999993 + 4229.040000000001, pl:-4.911000000000186, winRate:0.438
# statistics: [('average_q', 0.0021941152), ('average_loss', 1.1340470596366003e-07), ('cumulative_steps', 666042), ('n_updates', 133201), ('rlen', 100)]
# max steps
# budget:95874.23999999996 + 4425.4400000000005, pl:-4.741999999999933, winRate:0.4451219512195122
# statistics: [('average_q', 0.0025449542), ('average_loss', 2.2091905664822776e-07), ('cumulative_steps', 676042), ('n_updates', 135201), ('rlen', 100)]
# max steps
# budget:95792.8400000002 + 4158.44, pl:-4.601000000000681, winRate:0.42038216560509556
# statistics: [('average_q', 0.0002538865), ('average_loss', 1.7081644458016853e-07), ('cumulative_steps', 686042), ('n_updates', 137201), ('rlen', 100)]
# index end
# budget:91142.56000000001 + 8824.0, pl:0.228999999999985, winRate:0.4444444444444444
# statistics: [('average_q', 0.0018863755), ('average_loss', 1.9581896125941967e-07), ('cumulative_steps', 686958), ('n_updates', 137384), ('rlen', 100)]
# max steps
# budget:95868.16000000012 + 4142.960000000001, pl:-6.114999999999995, winRate:0.39337474120082816
# statistics: [('average_q', -0.00033377868), ('average_loss', 8.845986973149423e-08), ('cumulative_steps', 696958), ('n_updates', 139384), ('rlen', 100)]
# max steps
# budget:95779.32000000008 + 4169.079999999999, pl:-7.341000000000108, winRate:0.3903846153846154
# statistics: [('average_q', 0.005788765), ('average_loss', 5.738881304928611e-07), ('cumulative_steps', 706958), ('n_updates', 141384), ('rlen', 100)]
# max steps
# budget:91590.59999999989 + 8393.36, pl:-2.596000000000089, winRate:0.40848214285714285
# statistics: [('average_q', -0.004356795), ('average_loss', 1.6713411904234477e-07), ('cumulative_steps', 716958), ('n_updates', 143384), ('rlen', 100)]
# max steps
# budget:95767.99999999996 + 4219.360000000001, pl:-4.06699999999995, winRate:0.40332640332640335
# statistics: [('average_q', -0.002443921), ('average_loss', 7.744228485151438e-08), ('cumulative_steps', 726958), ('n_updates', 145384), ('rlen', 100)]
# max steps
# budget:95760.12 + 4137.280000000001, pl:-1.2400000000003075, winRate:0.42570281124497994
# statistics: [('average_q', 0.0024148687), ('average_loss', 3.644482502807023e-07), ('cumulative_steps', 736958), ('n_updates', 147384), ('rlen', 100)]
# max steps
# budget:91682.60000000022 + 8310.32, pl:-5.3110000000000355, winRate:0.40824742268041236
# statistics: [('average_q', 0.00044430568), ('average_loss', 1.721519594255483e-07), ('cumulative_steps', 746958), ('n_updates', 149384), ('rlen', 100)]
# max steps
# budget:91691.28000000004 + 8302.48, pl:-3.5680000000001684, winRate:0.42650103519668736
# statistics: [('average_q', 0.00014951166), ('average_loss', 9.868888801278785e-08), ('cumulative_steps', 756958), ('n_updates', 151384), ('rlen', 100)]
# max steps
# budget:95701.75999999986 + 4426.080000000001, pl:-5.0039999999997775, winRate:0.4024144869215292
# statistics: [('average_q', -0.002085183), ('average_loss', 1.447335636228786e-07), ('cumulative_steps', 766958), ('n_updates', 153384), ('rlen', 100)]
# max steps
# budget:95954.60000000041 + 4313.64, pl:-1.925000000000125, winRate:0.42283298097251587
# statistics: [('average_q', 0.0020661992), ('average_loss', 2.0265295521681992e-07), ('cumulative_steps', 776958), ('n_updates', 155384), ('rlen', 100)]
# max steps
# budget:95833.75999999998 + 4412.68, pl:-8.310000000000088, winRate:0.3784860557768924
# statistics: [('average_q', -0.0028240178), ('average_loss', 2.7842524914944987e-07), ('cumulative_steps', 786958), ('n_updates', 157384), ('rlen', 100)]
# max steps
# budget:95557.48000000029 + 4358.68, pl:-2.2939999999998832, winRate:0.4132231404958678
# statistics: [('average_q', -8.431703e-05), ('average_loss', 1.5989967664609139e-07), ('cumulative_steps', 796958), ('n_updates', 159384), ('rlen', 100)]
# max steps
# budget:95795.56000000004 + 4199.240000000001, pl:-6.182999999999993, winRate:0.4105461393596987
# statistics: [('average_q', 0.00026009823), ('average_loss', 1.4008395256226435e-07), ('cumulative_steps', 806958), ('n_updates', 161384), ('rlen', 100)]
# max steps
# budget:95770.20000000008 + 4186.960000000001, pl:-5.024999999999665, winRate:0.40077821011673154
# statistics: [('average_q', 0.0014282911), ('average_loss', 2.3143897674771098e-07), ('cumulative_steps', 816958), ('n_updates', 163384), ('rlen', 100)]
# max steps
# budget:95866.76000000015 + 4363.64, pl:-4.593999999999468, winRate:0.4032258064516129
# statistics: [('average_q', -0.0014716961), ('average_loss', 1.4678581482741039e-07), ('cumulative_steps', 826958), ('n_updates', 165384), ('rlen', 100)]
# max steps
# budget:95747.92000000014 + 4373.920000000001, pl:-4.532999999999589, winRate:0.3686274509803922
# statistics: [('average_q', -0.00043971802), ('average_loss', 3.2958949227612775e-07), ('cumulative_steps', 836958), ('n_updates', 167384), ('rlen', 100)]
# max steps
# budget:91575.35999999983 + 8351.12, pl:-2.674000000000106, winRate:0.40461215932914046
# statistics: [('average_q', -0.0007006606), ('average_loss', 2.2364330899193873e-07), ('cumulative_steps', 846958), ('n_updates', 169384), ('rlen', 100)]
# max steps
# budget:95767.59999999996 + 4155.08, pl:-2.61100000000026, winRate:0.42322834645669294
# statistics: [('average_q', 0.0010680675), ('average_loss', 1.7512054640178576e-07), ('cumulative_steps', 856958), ('n_updates', 171384), ('rlen', 100)]
# index end
# budget:91144.96000000006 + 8824.0, pl:-4.9249999999998835, winRate:0.41330166270783847
# statistics: [('average_q', 0.0005781239), ('average_loss', 1.7850931655516433e-07), ('cumulative_steps', 865645), ('n_updates', 173122), ('rlen', 100)]
# max steps
# budget:95803.63999999993 + 4164.72, pl:-5.317000000000263, winRate:0.37473684210526315
# statistics: [('average_q', -0.0044884603), ('average_loss', 3.121757378465873e-07), ('cumulative_steps', 875645), ('n_updates', 175122), ('rlen', 100)]
# max steps
# budget:95647.80000000031 + 4447.44, pl:-4.857000000000028, winRate:0.37524557956778
# statistics: [('average_q', -0.004276839), ('average_loss', 2.5912829800134317e-07), ('cumulative_steps', 885645), ('n_updates', 177122), ('rlen', 100)]
# index end
# budget:95560.71999999984 + 4411.88, pl:-4.0079999999998535, winRate:0.40350877192982454
# statistics: [('average_q', 5.2193627e-05), ('average_loss', 1.5431834402335198e-07), ('cumulative_steps', 893361), ('n_updates', 178665), ('rlen', 100)]
# max steps
# budget:95791.91999999994 + 4229.000000000001, pl:-9.374000000000379, winRate:0.3723404255319149
# statistics: [('average_q', -0.002590119), ('average_loss', 2.259795262204989e-07), ('cumulative_steps', 903361), ('n_updates', 180665), ('rlen', 100)]
# index end
# budget:95528.72000000002 + 4411.88, pl:-2.337999999999923, winRate:0.2894736842105263
# statistics: [('average_q', 0.0022341132), ('average_loss', 1.593234024532819e-07), ('cumulative_steps', 905092), ('n_updates', 181011), ('rlen', 100)]
# max steps
# budget:91527.2399999999 + 8442.080000000002, pl:-4.446000000000097, winRate:0.44421487603305787
# statistics: [('average_q', 0.0020712246), ('average_loss', 3.3718371575730546e-07), ('cumulative_steps', 915092), ('n_updates', 183011), ('rlen', 100)]
# max steps
# budget:95644.16000000018 + 4373.28, pl:-5.064000000000306, winRate:0.4025423728813559
# statistics: [('average_q', -0.0017188845), ('average_loss', 1.2448575279933038e-07), ('cumulative_steps', 925092), ('n_updates', 185011), ('rlen', 100)]
# index end
# budget:91144.95999999988 + 8824.0, pl:-2.4560000000002304, winRate:0.4200743494423792
# statistics: [('average_q', -0.004632938), ('average_loss', 1.6897361071244177e-07), ('cumulative_steps', 930558), ('n_updates', 186104), ('rlen', 100)]
# max steps
# budget:95751.12000000008 + 4148.68, pl:-2.208000000000297, winRate:0.39655172413793105
# statistics: [('average_q', 0.001474737), ('average_loss', 1.2261759401610562e-07), ('cumulative_steps', 940558), ('n_updates', 188104), ('rlen', 100)]
# max steps
# budget:95631.6 + 4402.96, pl:-4.855000000000075, winRate:0.3755186721991701
# statistics: [('average_q', 0.004955676), ('average_loss', 2.9905041664335386e-07), ('cumulative_steps', 950558), ('n_updates', 190104), ('rlen', 100)]
# index end
# budget:95570.36000000012 + 4412.12, pl:-2.8900000000000574, winRate:0.3844086021505376
# statistics: [('average_q', -0.0020054618), ('average_loss', 1.6062422460549898e-07), ('cumulative_steps', 958013), ('n_updates', 191595), ('rlen', 100)]
# max steps
# budget:95702.71999999972 + 4149.76, pl:-5.306000000000125, winRate:0.41164658634538154
# statistics: [('average_q', -0.0024042176), ('average_loss', 8.946788830677121e-08), ('cumulative_steps', 968013), ('n_updates', 193595), ('rlen', 100)]
# max steps
# budget:95706.56000000006 + 4379.48, pl:-4.121000000000279, winRate:0.41
# statistics: [('average_q', 0.005302142), ('average_loss', 1.6348978611802068e-07), ('cumulative_steps', 978013), ('n_updates', 195595), ('rlen', 100)]
# max steps
# budget:95580.07999999977 + 4373.84, pl:-7.52499999999965, winRate:0.4168336673346693
# statistics: [('average_q', 0.0032454287), ('average_loss', 1.7264865096677794e-07), ('cumulative_steps', 988013), ('n_updates', 197595), ('rlen', 100)]
# index end
# budget:95550.99999999996 + 4411.88, pl:-1.2170000000000272, winRate:0.4166666666666667
# statistics: [('average_q', -0.0023957381), ('average_loss', 3.2693294258479e-07), ('cumulative_steps', 989652), ('n_updates', 197923), ('rlen', 100)]
# max steps
# budget:95744.3199999998 + 4198.52, pl:-5.741000000000014, winRate:0.41836734693877553
# statistics: [('average_q', 0.002765155), ('average_loss', 1.4065010196517845e-07), ('cumulative_steps', 999652), ('n_updates', 199923), ('rlen', 100)]
# max steps
# budget:91621.51999999999 + 8349.44, pl:-3.2249999999997243, winRate:0.43067226890756305
# statistics: [('average_q', 0.0022651122), ('average_loss', 3.408434614016187e-07), ('cumulative_steps', 1009652), ('n_updates', 201923), ('rlen', 100)]
# max steps
# budget:95803.16000000002 + 4152.72, pl:-4.85300000000025, winRate:0.3895582329317269
# statistics: [('average_q', 0.00017344205), ('average_loss', 2.4983940804190753e-07), ('cumulative_steps', 1019652), ('n_updates', 203923), ('rlen', 100)]
# max steps
# budget:95601.48000000008 + 4356.6, pl:-4.369000000000355, winRate:0.4574898785425101
# statistics: [('average_q', 0.004098438), ('average_loss', 4.446323904261362e-07), ('cumulative_steps', 1029652), ('n_updates', 205923), ('rlen', 100)]
# index end
# budget:95531.44000000009 + 4411.88, pl:-3.9379999999999455, winRate:0.366412213740458
# statistics: [('average_q', -0.003360671), ('average_loss', 3.0604151683988335e-07), ('cumulative_steps', 1032066), ('n_updates', 206406), ('rlen', 100)]
# index end
# budget:95593.84000000014 + 4411.88, pl:-0.8239999999999981, winRate:0.37916666666666665
# statistics: [('average_q', -0.0014389324), ('average_loss', 2.6639380180881743e-07), ('cumulative_steps', 1036927), ('n_updates', 207378), ('rlen', 100)]
# max steps
# budget:95794.36000000009 + 4395.96, pl:-5.769999999999953, winRate:0.4099009900990099
# statistics: [('average_q', -0.0022198015), ('average_loss', 2.606844803310082e-07), ('cumulative_steps', 1046927), ('n_updates', 209378), ('rlen', 100)]
# max steps
# budget:95759.99999999977 + 4346.120000000001, pl:-3.3649999999998244, winRate:0.41359223300970877
# statistics: [('average_q', -0.000111335874), ('average_loss', 1.2442396991829695e-07), ('cumulative_steps', 1056927), ('n_updates', 211378), ('rlen', 100)]
# max steps
# budget:91208.24000000006 + 8712.400000000001, pl:-0.6300000000001944, winRate:0.4613778705636743
# statistics: [('average_q', 0.0016406645), ('average_loss', 1.1091719647637888e-07), ('cumulative_steps', 1066927), ('n_updates', 213378), ('rlen', 100)]
# index end
# budget:95557.24000000006 + 4412.12, pl:-0.614999999999938, winRate:0.3225806451612903
# statistics: [('average_q', -0.0038800712), ('average_loss', 2.8909225887829846e-07), ('cumulative_steps', 1067642), ('n_updates', 213521), ('rlen', 100)]
# index end
# budget:95564.64000000004 + 4411.88, pl:-1.643000000000029, winRate:0.4394904458598726
# statistics: [('average_q', -1.4471144e-05), ('average_loss', 1.79129836226366e-07), ('cumulative_steps', 1070724), ('n_updates', 214137), ('rlen', 100)]
# max steps
# budget:95705.87999999998 + 4189.0, pl:-2.2249999999999517, winRate:0.42
# statistics: [('average_q', 0.0011541764), ('average_loss', 1.434065530148132e-07), ('cumulative_steps', 1080724), ('n_updates', 216137), ('rlen', 100)]
# max steps
# budget:95849.91999999988 + 4172.68, pl:-6.233000000000558, winRate:0.4065040650406504
# statistics: [('average_q', -0.0031443713), ('average_loss', 2.999808427617268e-07), ('cumulative_steps', 1090724), ('n_updates', 218137), ('rlen', 100)]
# max steps
# budget:91269.56000000013 + 8728.24, pl:-6.185000000000187, winRate:0.4316831683168317
# statistics: [('average_q', -0.0026509445), ('average_loss', 1.1027968429999646e-07), ('cumulative_steps', 1100724), ('n_updates', 220137), ('rlen', 100)]
# max steps
# budget:91193.32000000005 + 8772.480000000001, pl:-5.248000000000047, winRate:0.4077079107505071
# statistics: [('average_q', -0.004445651), ('average_loss', 2.754783623259982e-07), ('cumulative_steps', 1110724), ('n_updates', 222137), ('rlen', 100)]
# max steps
# budget:91717.4799999999 + 8394.0, pl:-7.151000000000096, winRate:0.4239350912778905
# statistics: [('average_q', -0.0023943603), ('average_loss', 1.1051789940097478e-07), ('cumulative_steps', 1120724), ('n_updates', 224137), ('rlen', 100)]
# max steps
# budget:95698.56000000013 + 4393.0, pl:-6.205999999999861, winRate:0.38444924406047515
# statistics: [('average_q', 0.0010879169), ('average_loss', 2.8540643938868014e-07), ('cumulative_steps', 1130724), ('n_updates', 226137), ('rlen', 100)]
# max steps
# budget:91574.59999999985 + 8296.48, pl:-1.5910000000002213, winRate:0.4261954261954262
# statistics: [('average_q', -0.00014533752), ('average_loss', 1.0999438837089315e-07), ('cumulative_steps', 1140724), ('n_updates', 228137), ('rlen', 100)]
# max steps
# budget:95971.03999999985 + 4219.960000000001, pl:-7.510000000000247, winRate:0.3407258064516129
# statistics: [('average_q', -0.0014315764), ('average_loss', 5.592530905929039e-07), ('cumulative_steps', 1150724), ('n_updates', 230137), ('rlen', 100)]
# max steps
# budget:91653.48000000016 + 8264.960000000001, pl:-6.13999999999983, winRate:0.4050387596899225
# statistics: [('average_q', -0.002121618), ('average_loss', 1.9097079071883626e-07), ('cumulative_steps', 1160724), ('n_updates', 232137), ('rlen', 100)]
# max steps
# budget:91659.9600000001 + 8254.560000000001, pl:-8.702999999999832, winRate:0.3844660194174757
# statistics: [('average_q', 0.0021705714), ('average_loss', 1.817816330973443e-07), ('cumulative_steps', 1170724), ('n_updates', 234137), ('rlen', 100)]
# max steps
# budget:91610.84000000024 + 8350.64, pl:-4.945999999999742, winRate:0.3975659229208925
# statistics: [('average_q', 0.0017727384), ('average_loss', 3.0003906257292103e-07), ('cumulative_steps', 1180724), ('n_updates', 236137), ('rlen', 100)]
# max steps
# budget:95801.9999999999 + 4153.160000000001, pl:-4.247999999999962, winRate:0.38414634146341464
# statistics: [('average_q', -0.002294548), ('average_loss', 1.0316428159740099e-07), ('cumulative_steps', 1190724), ('n_updates', 238137), ('rlen', 100)]
# index end
# budget:95543.52000000008 + 4412.12, pl:-1.390999999999977, winRate:0.4012738853503185
# statistics: [('average_q', 0.00030528326), ('average_loss', 2.8634167414054446e-07), ('cumulative_steps', 1193923), ('n_updates', 238777), ('rlen', 100)]
# max steps
# budget:91614.71999999994 + 8403.52, pl:-5.161000000000158, winRate:0.41372141372141374
# statistics: [('average_q', -0.0012893813), ('average_loss', 1.0105120296088899e-07), ('cumulative_steps', 1203923), ('n_updates', 240777), ('rlen', 100)]
# index end
# budget:95610.63999999993 + 4412.12, pl:0.16799999999997794, winRate:0.40932642487046633
# statistics: [('average_q', -0.0018258472), ('average_loss', 3.885530967551176e-07), ('cumulative_steps', 1207951), ('n_updates', 241583), ('rlen', 100)]
# max steps
# budget:95915.59999999999 + 4217.08, pl:-4.396999999999693, winRate:0.39439655172413796
# statistics: [('average_q', 0.0012188541), ('average_loss', 1.2828957457244883e-07), ('cumulative_steps', 1217951), ('n_updates', 243583), ('rlen', 100)]
# max steps
# budget:95746.67999999993 + 4217.28, pl:-2.02799999999975, winRate:0.41541755888650966
# statistics: [('average_q', -0.0024648644), ('average_loss', 1.0767389186483455e-07), ('cumulative_steps', 1227951), ('n_updates', 245583), ('rlen', 100)]
# max steps
# budget:95498.7200000001 + 4350.120000000001, pl:-4.1369999999997304, winRate:0.38271604938271603
# statistics: [('average_q', 0.0005958809), ('average_loss', 1.2926436852467304e-07), ('cumulative_steps', 1237951), ('n_updates', 247583), ('rlen', 100)]
# max steps
# budget:91308.15999999989 + 8822.480000000001, pl:-2.685000000000173, winRate:0.41372141372141374
# statistics: [('average_q', 0.0024263188), ('average_loss', 3.1158424544486253e-07), ('cumulative_steps', 1247951), ('n_updates', 249583), ('rlen', 100)]
# max steps
# budget:95708.56000000011 + 4161.960000000001, pl:-3.234000000000023, winRate:0.40124740124740127
# statistics: [('average_q', 0.002187111), ('average_loss', 2.727357897391869e-07), ('cumulative_steps', 1257951), ('n_updates', 251583), ('rlen', 100)]
# max steps
# budget:91697.79999999987 + 8419.760000000002, pl:-4.316999999999879, winRate:0.40388349514563104
# statistics: [('average_q', -0.0008533632), ('average_loss', 1.0188081613904387e-06), ('cumulative_steps', 1267951), ('n_updates', 253583), ('rlen', 100)]
# max steps
# budget:95865.68000000004 + 4151.360000000001, pl:-6.668000000000035, winRate:0.41325536062378165
# statistics: [('average_q', 0.0029382901), ('average_loss', 1.606036536649924e-07), ('cumulative_steps', 1277951), ('n_updates', 255583), ('rlen', 100)]
# max steps
# budget:95921.24000000003 + 4273.200000000001, pl:-2.158000000000399, winRate:0.4090909090909091
# statistics: [('average_q', 0.0022196185), ('average_loss', 1.3242352402187409e-07), ('cumulative_steps', 1287951), ('n_updates', 257583), ('rlen', 100)]
# max steps
# budget:91245.56000000011 + 8840.560000000001, pl:-4.512000000000128, winRate:0.40976645435244163
# statistics: [('average_q', -0.0031953675), ('average_loss', 2.2459524977591628e-07), ('cumulative_steps', 1297951), ('n_updates', 259583), ('rlen', 100)]
# max steps
# budget:95965.76000000027 + 4362.8, pl:-7.870000000000118, winRate:0.4015594541910331
# statistics: [('average_q', -0.005062231), ('average_loss', 2.9108376072173313e-07), ('cumulative_steps', 1307951), ('n_updates', 261583), ('rlen', 100)]
# max steps
# budget:95689.84000000004 + 4358.200000000001, pl:-3.9230000000000302, winRate:0.4192872117400419
# statistics: [('average_q', -0.00051316), ('average_loss', 1.6930883624866056e-07), ('cumulative_steps', 1317951), ('n_updates', 263583), ('rlen', 100)]
# max steps
# budget:95927.23999999993 + 4220.24, pl:-7.736000000000146, winRate:0.3897216274089936
# statistics: [('average_q', -0.005096447), ('average_loss', 2.3771432310581987e-07), ('cumulative_steps', 1327951), ('n_updates', 265583), ('rlen', 100)]
# max steps
# budget:95780.28000000004 + 4164.76, pl:-1.663000000000082, winRate:0.44142259414225943
# statistics: [('average_q', -0.0015359985), ('average_loss', 3.059855026066316e-07), ('cumulative_steps', 1337951), ('n_updates', 267583), ('rlen', 100)]
# max steps
# budget:95912.40000000021 + 4185.44, pl:-4.987000000000393, winRate:0.39478957915831664
# statistics: [('average_q', -0.0016228635), ('average_loss', 2.2787886599928697e-07), ('cumulative_steps', 1347951), ('n_updates', 269583), ('rlen', 100)]
# max steps
# budget:95573.96000000012 + 4441.4800000000005, pl:-4.501999999999967, winRate:0.39923224568138194
# statistics: [('average_q', -0.0023937093), ('average_loss', 3.083775177969983e-07), ('cumulative_steps', 1357951), ('n_updates', 271583), ('rlen', 100)]
# max steps
# budget:91535.59999999989 + 8730.32, pl:-1.9989999999999952, winRate:0.445859872611465
# statistics: [('average_q', 0.0013986649), ('average_loss', 2.0149690151072262e-07), ('cumulative_steps', 1367951), ('n_updates', 273583), ('rlen', 100)]
# max steps
# budget:91189.24 + 8927.52, pl:-7.304000000000059, winRate:0.40643863179074446
# statistics: [('average_q', -7.619776e-05), ('average_loss', 2.807710595931212e-07), ('cumulative_steps', 1377951), ('n_updates', 275583), ('rlen', 100)]
# max steps
# budget:95724.59999999992 + 4216.48, pl:-4.557999999999851, winRate:0.4101010101010101
# statistics: [('average_q', -0.0045810114), ('average_loss', 2.3181506939806695e-07), ('cumulative_steps', 1387951), ('n_updates', 277583), ('rlen', 100)]
# index end
# budget:91150.36 + 8824.0, pl:-1.579999999999984, winRate:0.38028169014084506
# statistics: [('average_q', -0.0043306216), ('average_loss', 1.933480906046725e-07), ('cumulative_steps', 1389431), ('n_updates', 277879), ('rlen', 100)]
# max steps
# budget:91593.8800000001 + 8545.119999999999, pl:-4.187000000000296, winRate:0.4024640657084189
# statistics: [('average_q', -0.0011471008), ('average_loss', 2.042896868204025e-07), ('cumulative_steps', 1399431), ('n_updates', 279879), ('rlen', 100)]
# max steps
# budget:95936.71999999994 + 4364.960000000001, pl:-5.0330000000003, winRate:0.42616033755274263
# statistics: [('average_q', 0.00027973927), ('average_loss', 2.4796369341828494e-07), ('cumulative_steps', 1409431), ('n_updates', 281879), ('rlen', 100)]
# max steps
# budget:95761.28000000016 + 4223.320000000001, pl:-5.791000000000125, winRate:0.42330097087378643
# statistics: [('average_q', -0.0030962566), ('average_loss', 1.4992712806360943e-07), ('cumulative_steps', 1419431), ('n_updates', 283879), ('rlen', 100)]
# index end
# budget:95527.04 + 4412.12, pl:-2.0, winRate:0.3918918918918919
# statistics: [('average_q', -0.0014211196), ('average_loss', 2.1199644947955676e-07), ('cumulative_steps', 1420908), ('n_updates', 284174), ('rlen', 100)]
# max steps
# budget:91577.83999999981 + 8392.400000000001, pl:-7.563000000000258, winRate:0.3630705394190871
# statistics: [('average_q', -0.0013839068), ('average_loss', 3.474235794698188e-07), ('cumulative_steps', 1430908), ('n_updates', 286174), ('rlen', 100)]
# max steps
# budget:91452.00000000022 + 8767.2, pl:-9.232000000000099, winRate:0.3831041257367387
# statistics: [('average_q', -0.0022457393), ('average_loss', 2.3997768083816595e-07), ('cumulative_steps', 1440908), ('n_updates', 288174), ('rlen', 100)]
# max steps
# budget:95698.75999999985 + 4403.68, pl:-7.144999999999854, winRate:0.378
# statistics: [('average_q', -0.0018851392), ('average_loss', 9.607109920040102e-08), ('cumulative_steps', 1450908), ('n_updates', 290174), ('rlen', 100)]
# index end
# budget:95579.59999999993 + 4412.12, pl:-3.4909999999997297, winRate:0.34814814814814815
# statistics: [('average_q', -0.0011800937), ('average_loss', 1.73437114021624e-07), ('cumulative_steps', 1453887), ('n_updates', 290770), ('rlen', 100)]
# index end
# budget:95601.08 + 4411.88, pl:-3.8950000000000813, winRate:0.3850267379679144
# statistics: [('average_q', -0.0015371442), ('average_loss', 1.8828426162187384e-07), ('cumulative_steps', 1457459), ('n_updates', 291484), ('rlen', 100)]
# max steps
# budget:91594.68000000014 + 8426.160000000002, pl:-4.072000000000358, winRate:0.3806818181818182
# statistics: [('average_q', -0.0021439502), ('average_loss', 1.5066746257730302e-07), ('cumulative_steps', 1467459), ('n_updates', 293484), ('rlen', 100)]
# index end
# budget:95545.24000000005 + 4411.88, pl:0.042999999999992156, winRate:0.5
# statistics: [('average_q', 0.0021802594), ('average_loss', 3.424531952944676e-07), ('cumulative_steps', 1469650), ('n_updates', 293923), ('rlen', 100)]
# max steps
# budget:91671.00000000017 + 8340.64, pl:-5.249000000000166, winRate:0.39549180327868855
# statistics: [('average_q', -0.00024058987), ('average_loss', 1.2848930175834993e-07), ('cumulative_steps', 1479650), ('n_updates', 295923), ('rlen', 100)]
# max steps
# budget:91530.04000000014 + 8434.240000000002, pl:-4.549000000000007, winRate:0.4112903225806452
# statistics: [('average_q', 0.0011038623), ('average_loss', 3.3545822155645053e-07), ('cumulative_steps', 1489650), ('n_updates', 297923), ('rlen', 100)]
# max steps
# budget:95765.64000000007 + 4131.400000000001, pl:-6.340000000000231, winRate:0.3803921568627451
# statistics: [('average_q', -0.002283587), ('average_loss', 1.9360828027004118e-07), ('cumulative_steps', 1499650), ('n_updates', 299923), ('rlen', 100)]
# max steps
# budget:95917.63999999998 + 4316.320000000001, pl:-7.2289999999999, winRate:0.39501039501039503
# statistics: [('average_q', 0.0022937004), ('average_loss', 1.9282118870478371e-07), ('cumulative_steps', 1509650), ('n_updates', 301923), ('rlen', 100)]
# max steps
# budget:95782.0800000001 + 4208.72, pl:-6.592000000000169, winRate:0.3958333333333333
# statistics: [('average_q', 0.00045306355), ('average_loss', 1.4115516314916476e-07), ('cumulative_steps', 1519650), ('n_updates', 303923), ('rlen', 100)]
# max steps
# budget:91238.00000000007 + 8714.400000000001, pl:-5.759000000000171, winRate:0.36065573770491804
# statistics: [('average_q', -0.0038206314), ('average_loss', 1.8066107980274636e-07), ('cumulative_steps', 1529650), ('n_updates', 305923), ('rlen', 100)]
# max steps
# budget:95904.91999999981 + 4387.44, pl:-5.242000000000118, winRate:0.41855670103092785
# statistics: [('average_q', -0.0019853553), ('average_loss', 1.768194502282938e-07), ('cumulative_steps', 1539650), ('n_updates', 307923), ('rlen', 100)]
# max steps
# budget:95774.71999999996 + 4210.76, pl:-7.622000000000355, winRate:0.41164241164241167
# statistics: [('average_q', -0.0026291055), ('average_loss', 1.350059971372275e-07), ('cumulative_steps', 1549650), ('n_updates', 309923), ('rlen', 100)]
# max steps
# budget:95775.60000000014 + 4216.52, pl:-3.270999999999759, winRate:0.3675564681724846
# statistics: [('average_q', -0.0010062668), ('average_loss', 1.3278508230740728e-07), ('cumulative_steps', 1559650), ('n_updates', 311923), ('rlen', 100)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a0b9117df984> in <module>
#      10         # Uncomment to watch the behavior in a GUI window
#      11         #env.render()
# ---> 12         action = agent.act(obs)
#      13         obs, reward, done, ops = env.step(action)
#      14         #obs = obs.to('cpu').detach().numpy().copy()
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/pfrl/agent.py in act(self, obs)
#     159
#     160     def act(self, obs: Any) -> Any:
# --> 161         return self.batch_act([obs])[0]
#     162
#     163     def observe(self, obs: Any, reward: float, done: bool, reset: bool) -> None:
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/pfrl/agents/dqn.py in batch_act(self, batch_obs)
#     488     def batch_act(self, batch_obs: Sequence[Any]) -> Sequence[Any]:
#     489         with torch.no_grad(), evaluating(self.model):
# --> 490             batch_av = self._evaluate_model_and_update_recurrent_states(batch_obs)
#     491             batch_argmax = batch_av.greedy_actions.detach().cpu().numpy()
#     492         if self.training:
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/pfrl/agents/dqn.py in _evaluate_model_and_update_recurrent_states(self, batch_obs)
#     483                 )
#     484         else:
# --> 485             batch_av = self.model(batch_xs)
#     486         return batch_av
#     487
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-4-914e777bf69e> in forward(self, inputs)
#      30         out = F.relu(self.fc1(out))
#      31         out = F.relu(self.fc2(out))
# ---> 32         out = self.output_layer(out)
#      33         return pfrl.action_value.DiscreteActionValue(out)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:

# %% [markdown]
# ### env.observation

# %%
obs.shape

# %%
reset
